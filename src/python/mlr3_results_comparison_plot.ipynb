# %%
_2prev = [0.742, 0.737, 0.708,0.715,0.705,0.76,0.813,0.725,0.687,0.797]
_2diff = [0.718,0.721,0.688,0.736,0.735,0.746,0.799,0.752,0.736,0.795]
_3 = [0.712,0.746,0.69,0.724,0.729,0.758,0.797,0.743,0.7,0.796]
_3prevprev = [0.708,0.719,0.7,0.756,0.745,0.747,0.799,0.737,0.735,0.801]
_4 =[0.732,0.736,0.711,0.729,0.721,0.754,0.802,0.749,0.72,0.79]
_5 = [0.689,0.71,0.695,0.756,0.717,0.761,0.804,0.74,0.727,0.793]
_6 = [0.691,0.721,0.728,0.754,0.736,0.754,0.816,0.743,0.728,0.766]
all = [0.747,0.719,0.727,0.729,0.72,0.779,0.79,0.728,0.718,0.778]
#make bar plot
import matplotlib.pyplot as plt
import numpy as np

N = 10
width = 0.15       # the width of the bars
space = 0.30        # space between the groups
ind = np.arange(N) * (width * 7 + space)  # the x locations for the groups

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111)

yvals = _2prev
rects1 = ax.bar(ind, yvals, width, color='r')
zvals = _2diff
rects2 = ax.bar(ind+width, zvals, width, color='g')
kvals = _3
rects3 = ax.bar(ind+width*2, kvals, width, color='b')
kvals = _3prevprev
rects4 = ax.bar(ind+width*3, kvals, width, color='y')
kvals = _4
rects5 = ax.bar(ind+width*4, kvals, width, color='m')
kvals = _5
rects6 = ax.bar(ind+width*5, kvals, width, color='c')
kvals = _6
rects7 = ax.bar(ind+width*6, kvals, width, color='0.75')
kvals = all
rects8 = ax.bar(ind+width*7, kvals, width, color='k')

ax.set_ylabel('AUC ROC score')
ax.set_ylim([0.6, 0.9])  # Set the limits of the y-axis
ax.set_xticks(ind+width*3)
ax.set_xticklabels( ('6-8\nNeuroblasts', '6-8\nNeurons', '6-8\nGlia', '10-12\nNeuroblasts', '10-12\nNeurons', '10-12\nGlia', '14-16\nNeuroblasts', '14-16\nNeurons', '14-16\nGlia', '16-18\nwhole_embryo') )
ax.legend( (rects1[0], rects2[0], rects3[0], rects4[0], rects5[0], rects6[0], rects7[0], rects8[0]), ('2prev', '2diff', '3', '3prevprev', '4', '5', '6', 'all') )
plt.show()

# %%
_2prev = [0.754, 0.773,0.745]
_2diff = [0.756,0.764,0.722]
_3 = [0.772,0.772,0.734]
_3prevprev = [0.773,0.775,0.736]
_4 = [0.773,0.784,0.739]
_5 = [0.775,0.775,0.737]
_6 = [0.782, 0.766,0.732]

N = 3
width = 0.15       # the width of the bars
space = 0.30        # space between the groups
ind = np.arange(N) * (width * 7 + space)  # the x locations for the groups

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111)

yvals = _2prev
rects1 = ax.bar(ind, yvals, width, color='r')
zvals = _2diff
rects2 = ax.bar(ind+width, zvals, width, color='g')
kvals = _3
rects3 = ax.bar(ind+width*2, kvals, width, color='b')
kvals = _3prevprev
rects4 = ax.bar(ind+width*3, kvals, width, color='y')
kvals = _4
rects5 = ax.bar(ind+width*4, kvals, width, color='m')
kvals = _5
rects6 = ax.bar(ind+width*5, kvals, width, color='c')
kvals = _6
rects7 = ax.bar(ind+width*6, kvals, width, color='0.75')

ax.set_ylabel('AUC ROC score')
ax.set_ylim([0.65, 0.85])  # Set the limits of the y-axis
ax.set_xticks(ind+width*3)
ax.set_xticklabels( ('Neuroblasts', 'Neurons', 'Glia') )
ax.legend( (rects1[0], rects2[0], rects3[0], rects4[0], rects5[0], rects6[0], rects7[0]), ('2prev', '2diff', '3', '3prevprev', '4', '5', '6') )
plt.show()

# zmajoryzowany jest tylko 3prevprev, 2 diff i 3
